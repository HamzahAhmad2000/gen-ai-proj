# %%
# !git clone https://github.com/huggingface/pytorch-pretrained-BigGAN.git
# !cd pytorch-pretrained-BigGAN
# !pip install -r full_requirements.txt
# Out:
# Cloning into 'pytorch-pretrained-BigGAN'...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'full_requirements.txt'

# %%
import torch
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample,
                                       save_as_images, display_in_terminal)

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import logging
logging.basicConfig(level=logging.INFO)

# Load pre-trained model tokenizer (vocabulary)
model = BigGAN.from_pretrained('biggan-deep-256')

# Prepare a input
truncation = 0.4
class_vector = one_hot_from_names(['soap bubble', 'coffee', 'mushroom'], batch_size=3)
noise_vector = truncated_noise_sample(truncation=truncation, batch_size=3)

# All in tensors
noise_vector = torch.from_numpy(noise_vector)
class_vector = torch.from_numpy(class_vector)

# If you have a GPU, put everything on cuda
noise_vector = noise_vector.to('cuda')
class_vector = class_vector.to('cuda')
model.to('cuda')

# Generate an image
with torch.no_grad():
    output = model(noise_vector, class_vector, truncation)

# If you have a GPU put back on CPU
output = output.to('cpu')

# If you have a sixtel compatible terminal you can display the images in the terminal
# (see https://github.com/saitoha/libsixel for details)
display_in_terminal(output)

# Save results as png images
save_as_images(output)
# Out:
# INFO:pytorch_pretrained_biggan.file_utils:https://s3.amazonaws.com/models.huggingface.co/biggan/biggan-deep-256-pytorch_model.bin not found in cache, downloading to C:\Users\Codew\AppData\Local\Temp\tmpdni6eikq
# 100%|██████████| 234411737/234411737 [00:37<00:00, 6222866.13B/s]
# INFO:pytorch_pretrained_biggan.file_utils:copying C:\Users\Codew\AppData\Local\Temp\tmpdni6eikq to cache at C:\Users\Codew\.pytorch_pretrained_biggan\e7d036ee69a83e83503c46902552573b27d856eaf6b8b84252a63a715dce7501.aec5caf3e5c5252b8857d6bb8adefa8d1d6092a8ba6c9aaed1e6678f8a46be43
# INFO:pytorch_pretrained_biggan.file_utils:creating metadata file for C:\Users\Codew\.pytorch_pretrained_biggan\e7d036ee69a83e83503c46902552573b27d856eaf6b8b84252a63a715dce7501.aec5caf3e5c5252b8857d6bb8adefa8d1d6092a8ba6c9aaed1e6678f8a46be43
# INFO:pytorch_pretrained_biggan.file_utils:removing temp file C:\Users\Codew\AppData\Local\Temp\tmpdni6eikq
# ...

# %%
import json
import os
from PIL import Image
import torch
from transformers import CLIPTokenizer, CLIPModel
from torchvision import transforms

# Paths
json_file_path = r"C:\Users\Codew\OneDrive\Desktop\Gen Ai Proj\output_descriptions.json"  # Replace with the actual path
images_dir = r"C:\Users\Codew\OneDrive\Desktop\Gen Ai Proj\subfolder-10\ "       # Replace with the actual path
output_dir = "output/"       # Replace with the actual path

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Load CLIP model and tokenizer for text embeddings
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-base-patch32")
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
model.eval()

# Image transformations
image_transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize to BigGAN input size
    transforms.ToTensor(),          # Convert to tensor
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  # Normalize to [-1, 1]
])

# Load JSON file
with open(json_file_path, "r") as file:
    data = json.load(file)

# Preprocess data
preprocessed_data = []

for image_path, text in data.items():
    try:
        # Load and preprocess image
        full_image_path = os.path.join(images_dir, image_path)
        image = Image.open(full_image_path).convert("RGB")  # Ensure RGB format
        image_tensor = image_transform(image)

        # Tokenize and encode text
        inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
        with torch.no_grad():
            text_embedding = model.get_text_features(**inputs).squeeze(0)

        # Save processed image and embedding
        output_image_path = os.path.join(output_dir, os.path.basename(image_path))
        torch.save(image_tensor, output_image_path + ".pt")

        output_text_path = output_image_path.replace(".png", ".text.pt")
        torch.save(text_embedding, output_text_path)

        # Append metadata for reference
        preprocessed_data.append({
            "image_tensor_path": output_image_path + ".pt",
            "text_embedding_path": output_text_path,
            "original_text": text
        })

    except Exception as e:
        print(f"Error processing {image_path}: {e}")

# Save preprocessed metadata
metadata_path = os.path.join(output_dir, "metadata.json")
with open(metadata_path, "w") as file:
    json.dump(preprocessed_data, file, indent=4)

print(f"Preprocessing complete. Data saved to {output_dir}.")
# Out:
# c:\Users\Codew\anaconda3\envs\nlp\Lib\site-packages\PIL\Image.py:3218: DecompressionBombWarning: Image size (141750000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Preprocessing complete. Data saved to output/.
